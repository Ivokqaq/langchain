# %% [markdown]
# # 调用模型方式

# %%
# 硬解码
from langchain_openai import ChatOpenAI

chat_model = ChatOpenAI(
    model="gpt-4o-mini",
    base_url="https://api.openai-proxy.org/v1",
    api_key="sk-RaIJCz2pq14IZjIUB0gNPjp2OPFOLlT9XjeC8z2jEbkgqn11"
)

response = chat_model.invoke("什么是langchain")

print(response.content)
# Out:
# LangChain 是一个用于构建基于语言模型（如 GPT-3、GPT-4 等）的应用程序的框架。它旨在简化和加速与大型语言模型的集成和开发，提供了开发者需要的各种工具和组件，使得处理自然语言的任务变得更加高效和容易。
#
# LangChain 的核心功能包括：
#
# 1. **文档处理**：能够处理和分析文本数据，比如从文件、网页等来源提取信息。
# 2. **链式调用**：支持将多个处理步骤串联起来，通过“链”的方式处理复杂任务。
# 3. **记忆功能**：允许应用在会话中保持上下文和记忆，提高交互的连贯性和智能性。
# 4. **与外部系统的集成**：可以方便地与数据库、API等外部系统连接，实现更复杂的功能。
#
# LangChain 适用于各种应用场景，包括但不限于智能客服、内容生成、信息检索等领域。通过使用 LangChain，开发者可以更加专注于业务逻辑，而不必过多关注底层的实现细节。

# %%
# 使用环境变量
from langchain_openai import ChatOpenAI
import os

chat_model = ChatOpenAI(
    model="gpt-4o-mini",
    base_url=os.environ["OPENAI_BASE_URL"],
    api_key=os.environ["OPENAI_API_KEY"]
)

response = chat_model.invoke("什么是langchain")

print(response.content)

# %%
# 使用配置文件
from langchain_openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv()

chat_model = OpenAI(
    model="gpt-4o-mini",
    base_url=os.getenv("OPENAI_BASE_URL"),
    api_key=os.getenv("OPENAI_API_KEY1")
)

response = chat_model.invoke("什么是langchain")

print(response)
# Out:
# ，以及如何使用它来构建语言模型应用程序。
# * Langchain的主要组件：链、代理、数据加载器、文档检索、提示模板、LLM（大型语言模型）等。
# * LLM的使用：如何选择和使用不同的LLM（如OpenAI GPT、Hugging Face Transformers等）来完成特定的任务。
#
# 为了更好地理解Langchain，以下是一些您可以尝试的具体例子：
#
# 1. **创建一个简单的问答系统**：
#    使用Langchain构建一个简单的问答系统，将用户输入的问题传递给LLM，并返回答案。
#
# 2. **文本摘要**：
#    使用Langchain构建一个文本摘要应用程序，将给定的长文本传递给LLM，并生成简洁的摘要。
#
# 3. **对话系统**：
#    使用Langchain构建一个简单的对话系统，允许用户与LLM进行对话，并保持上下文。
#
# 4. **文档检索**：
#    使用Langchain实现文档检索功能，从一组文档中检索与用户问题相关的信息。
#
# 通过这些示例，您将能够更好地理解Langchain的功能和用途

# %%
# 使用配置文件
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY1")

chat_model = ChatOpenAI(
    model="gpt-4o-mini"
)

response = chat_model.invoke("什么是langchain")

print(response.content)
# Out:
# LangChain 是一个用于构建基于语言模型应用程序的框架。它提供了一组工具和模块，使开发者能够轻松地将不同的语言模型和相关技术集成到他们的应用中。LangChain 主要特别关注的领域包括：
#
# 1. **链式调用**：可以将多个组件（如语言模型、数据加载器等）组合在一起，形成一个处理流程。
# 2. **数据连接**：支持与各种数据源（如数据库、API 和文档）进行交互，能够进行高效的数据检索和处理。
# 3. **工具整合**：提供与多个外部工具和服务的接口，增强用户体验。
# 4. **功能模块**：封装了常见的任务和功能，如文本生成、对话管理等，使得开发者可以快速实现应用。
#
# 总的来说，LangChain 是一个强大的工具，旨在简化和加速与语言模型相关的应用开发。

# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY1")

chat_model = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.7,
    max_tokens=20
)

response = chat_model.invoke("什么是langchain")

print(response.content)
# Out:
# LangChain 是一个用于构建与语言模型交互的应用程序的框架。它

# %% [markdown]
# # 关于对话模型中消息(message)的使用

# %%
from langchain_openai import ChatOpenAI
import os
import dotenv

dotenv.load_dotenv()

os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY1")

chat_model = ChatOpenAI(
    # api_key=,
    # ase_url=,
    model="gpt-4o-mini"
)

# %%
from langchain_core.messages import SystemMessage, HumanMessage

system_message = SystemMessage(content="你是一个英语教学方向的专家")
human_message = HumanMessage(content="请帮我制定一个雅学习计划思")

messages = [system_message, human_message]
print(messages)
# Out:
# [SystemMessage(content='你是一个英语教学方向的专家', additional_kwargs={}, response_metadata={}), HumanMessage(content='请帮我制定一个雅思学习计划', additional_kwargs={}, response_metadata={})]

# %%
response = chat_model.invoke(messages)
print(response.content)
# Out:
# 当然可以！以下是一个为期8周的雅思学习计划，适用于希望在听力、阅读、写作和口语方面全面提升的考生。可以根据自己的时间安排和基础进行调整。
#
# ### 雅思学习计划（8周）
#
# #### 第1周：了解雅思考试
# - **目标**：
#   - 了解雅思考试的结构、评分标准及各部分内容。
# - **任务**：
#   - 阅读雅思官方网站上的相关信息，了解听、说、读、写四个部分的要求。
#   - 进行一份完整的模拟测试，评估自己目前的位置。
#
# #### 第2周：听力技巧
# - **目标**：
#   - 提升听力理解能力和技巧。
# - **任务**：
#   - 每天听雅思听力练习材料，重点关注不同口音（英、澳、美）和语速；
#   - 练习记录关键信息和细节，进行错题分析。
#
# #### 第3周：阅读技巧
# - **目标**：
#   - 提高阅读速度和理解能力。
# - **任务**：
#   - 每天阅读雅思阅读练习，学习快速浏览和扫读技巧；
#   - 学习如何有效管理时间，避免在某个题目上花费过多时间。
#
# #### 第4周：写作技巧
# - **目标**：
#   - 熟悉雅思写作任务一和任务二的要求。
# - **任务**：
#   - 每周完成两篇写作练习，任务一和任务二各一篇；
#   - 学习雅思写作常用句型，增加词汇量。
#
# #### 第5周：口语技巧
# - **目标**：
#   - 提高口语表达能力和流利度。
# - **任务**：
#   - 每天进行口语练习，可以与学习伙伴或老师进行对话练习；
#   - 练习常见话题，可以录制自己的回答并进行回放自我分析。
#
# #### 第6周：综合练习
# - **目标**：
#   - 针对弱项进行集中练习。
# - **任务**：
#   - 根据之前的模拟测试，找出最薄弱的部分，进行针对性练习；
#   - 完成一套完整的雅思模拟考试，检验学习成果。
#
# #### 第7周：调整和模拟
# - **目标**：
#   - 进行最后的调整，强化应试技巧。
# - **任务**：
#   - 进行至少两次完整的雅思模拟考试，按真实考试时间安排；
#   - 针对模拟考试中的薄弱环节进行单独练习。
#
# #### 第8周：心理准备与冲刺
# - **目标**：
#   - 调整心态，保持健康的学习方式。
# - **任务**：
#   - 复习错题，巩固重点知识；
#   - 进行简单的放松练习，保持良好的心态，确保考试当天轻松自信。
#
# ### 附加建议
# - **每天坚持**：每天都要安排至少2-3小时的学习时间，可以根据自己的节奏调整。
# - **制定学习目标**：为每周和每天设定具体的学习目标，保持动力。
# - **资源使用**：可以使用雅思真题、学习书籍（如《剑桥雅思系列》）、在线课程或手机应用程序。
#
# 希望这个计划能够帮助你有效地准备雅思考试，加油！如果有其他问题，欢迎随时问我。

# %% [markdown]
# ## 大模型本身没有上下文记忆

# %%
from langchain_openai import ChatOpenAI
import os
import dotenv

dotenv.load_dotenv()

os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY1")

chat_model = ChatOpenAI(
    # api_key=,
    # ase_url=,
    model="gpt-4o-mini"
)

# %%
from langchain_core.messages import SystemMessage, HumanMessage

system_message = SystemMessage(content="我是一个人工智能助手，我的名字叫小智")
human_message = HumanMessage(content="猫王是一只猫吗")

messages = [system_message, human_message]
response = chat_model.invoke(messages)
print(response.content)

response1 = chat_model.invoke("你叫什么名字？")
print(response1.content)
# Out:
# 猫王（Elvis Presley）并不是一只猫，而是美国著名的摇滚歌手和演员。他被誉为“摇滚之王”，以其独特的音乐风格和舞台魅力闻名于世。不过，如果你是在提到某个以“猫王”命名的猫角色或形象，那可能是指某个可爱的猫咪。如果有具体的角色或故事，请告诉我！
# 我是一个人工智能助手，没有具体的名字。你可以叫我助手或者你喜欢的其他名字！有什么我可以帮助你的吗？

# %% [markdown]
# # 模型调用方法

# %%
from langchain_openai import ChatOpenAI
import os
import dotenv
from langchain_core.messages import SystemMessage, HumanMessage

dotenv.load_dotenv()

os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY1")

chat_model = ChatOpenAI(
    # api_key=,
    # ase_url=,
    model="gpt-4o-mini"
)

messages = [HumanMessage(content="你好，请介绍一下自己")]

response = chat_model.invoke(messages)

print(response)
# Out:
# content='你好！我是一个人工智能助手，旨在提供信息、回答问题和帮助解决各种问题。我可以支持多种主题，包括科技、历史、文化、教育等。如果你有什么具体的问题或需要了解的内容，请随时问我！' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 12, 'total_tokens': 64, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_efad92c60b', 'id': 'chatcmpl-CY3QK6kQ7InwCI4OurWCbU2S7w37T', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--d117e18b-7bda-446f-b692-7fdc8be77f92-0' usage_metadata={'input_tokens': 12, 'output_tokens': 52, 'total_tokens': 64, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain_openai import ChatOpenAI
import os
import dotenv
from langchain_core.messages import SystemMessage, HumanMessage

dotenv.load_dotenv()

os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY1")

chat_model = ChatOpenAI(
    model="gpt-4o-mini",
    streaming=True
)

messages = [HumanMessage(content="你好，请介绍一下自己")]

print("开始流式输出：")
for chunk in chat_model.stream(messages):
    print(chunk.content, end="", flush=True)
print("\n流式输出结束")
# Out:
# 开始流式输出：
# 你好！我是一个人工智能助手，旨在帮助回答问题、提供信息和支持各种任务。我可以处理多种主题，从科学、历史到技术和文化等。如果你有任何具体的问题或需要帮助的地方，请随时告诉我！
# 流式输出结束

# %% [markdown]
# # 提示词模板

# %%
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate(
    template="你是一个{role}, 你的名字叫{name}",
    input_variables=["role", "name"]
)

prompt = prompt_template.format(role="人工智能专家", name="小智")
print(prompt)
# Out:
# 你是一个人工智能专家, 你的名字叫小智

# %%
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template(
    template="你是一个{role}, 你的名字叫{name}",
)

prompt = prompt_template.format(role="人工智能专家", name="小智")
print(prompt)
# Out:
# 你是一个人工智能专家, 你的名字叫小智

# %%
from langchain_core.prompts import PromptTemplate

text = """
Tell me a joke
"""

prompt_template = PromptTemplate.from_template(text)

prompt = prompt_template.format()
print(prompt)
# Out:
# Tell me a joke

# %%
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template(
    template="请评价{product}的优缺点，包括{aspect1}和{aspect2}。",
    partial_variables={"aspect1":"电池续航"}
)

prompt = prompt_template.format(product="智能手机", aspect2="拍照质量")
print(prompt)
# Out:
# 请评价智能手机的优缺点，包括电池续航和拍照质量。

# %%
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template(
    template="请评价{product}的优缺点，包括{aspect1}和{aspect2}。"
).partial(aspect1="电池续航", aspect2="拍照质量")

prompt = prompt_template.format(product="智能手机")
print(prompt)
print(type(prompt))
# Out:
# 请评价智能手机的优缺点，包括电池续航和拍照质量。
# <class 'str'>

# %%
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template(
    template="请评价{product}的优缺点，包括{aspect1}和{aspect2}。"
)

prompt = prompt_template.invoke(input={"product":"智能手机", "aspect1":"电池续航", "aspect2":"拍照质量"})
print(prompt)
print(type(prompt))
# Out:
# text='请评价智能手机的优缺点，包括电池续航和拍照质量。'
# <class 'langchain_core.prompt_values.StringPromptValue'>

# %%
from langchain_openai import ChatOpenAI
import os
import dotenv
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_core.prompts import PromptTemplate

dotenv.load_dotenv()

os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY1")

chat_model = ChatOpenAI(
    # api_key=,
    # ase_url=,
    model="gpt-4o-mini"
)

prompt_template = PromptTemplate.from_template(
    template="请评价{product}的优缺点，包括{aspect1}和{aspect2}。"
)

prompt = prompt_template.invoke(input={"product":"智能手机", "aspect1":"电池续航", "aspect2":"拍照质量"})

response = chat_model.invoke(prompt)

print(response.content)
# Out:
# 智能手机作为现代生活中不可或缺的设备，具有诸多优缺点。以下是对智能手机的一些优缺点的分析，特别关注电池续航和拍照质量：
#
# ### 优点
#
# 1. **便利性**：智能手机集成了多种功能，包括通信、上网、社交媒体、导航、娱乐等，使得日常生活非常便利。
#
# 2. **拍照质量**：许多智能手机配备高质量的摄像头，支持多种拍摄模式和高级功能，如夜景模式、HDR、4K视频录制等。这使得用户能够随时捕捉生活中的重要瞬间。
#
# 3. **应用生态**：智能手机平台上有丰富的应用程序可供下载，满足用户各种需求，从游戏、办公到健康管理等。
#
# 4. **更新与支持**：大多数智能手机品牌会定期推出系统更新和安全补丁，提升设备的安全性和功能性。
#
# 5. **便携性**：智能手机体积小，易于携带，用户可以随时随地进行各种活动。
#
# ### 缺点
#
# 1. **电池续航**：虽然智能手机的功能强大，但高性能的应用和频繁的使用会导致电池续航问题。很多智能手机在高负荷使用下，电池续航不足，用户需要频繁充电。
#
# 2. **拍照质量的局限性**：虽然智能手机的拍照功能在不断提升，但在某些情况下（如低光环境、大远景等），拍照质量仍然难以与专业相机相媲美。此外，镜头的光圈、传感器大小等硬件限制也影响最终效果。
#
# 3. **依赖性与注意力分散**：过度依赖智能手机可能导致注意力分散和社交疏离，影响人际关系和心理健康。
#
# 4. **价格问题**：高端智能手机价格普遍较高，且随着技术更新，过时的设备可能需要频繁更换。这增加了用户的经济负担。
#
# 5. **隐私与安全**：智能手机的使用涉及大量个人数据，安全性问题也随之而来。用户的隐私可能面临泄露风险，特别是在使用公共网络时。
#
# ### 结论
#
# 智能手机在便利性和功能性方面具有显著优势，但在电池续航和拍照质量等方面仍存在一定限制。用户在选择智能手机时，应该根据自己的需求和使用习惯，权衡这些优缺点，从而做出合适的选择。

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate([
    ("system", "你是一个AI助手，你的名字叫{name}"),
    ("human", "我的问题是{question}")
])

response = chat_prompt_template.invoke({"name":"小智", "question":"1 + 2 * 3 = ?"})
print(response)
# Out:
# messages=[SystemMessage(content='你是一个AI助手，你的名字叫小智', additional_kwargs={}, response_metadata={}), HumanMessage(content='我的问题是1 + 2 * 3 = ?', additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "你是一个AI助手，你的名字叫{name}"),
    ("human", "我的问题是{question}")
])

response = chat_prompt_template.invoke({"name":"小智", "question":"1 + 2 * 3 = ?"})
print(response)
print(type(response))
# Out:
# messages=[SystemMessage(content='你是一个AI助手，你的名字叫小智', additional_kwargs={}, response_metadata={}), HumanMessage(content='我的问题是1 + 2 * 3 = ?', additional_kwargs={}, response_metadata={})]
# <class 'langchain_core.prompt_values.ChatPromptValue'>

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "你是一个AI助手，你的名字叫{name}"),
    ("human", "我的问题是{question}")
])

response = chat_prompt_template.format(name="小智", question="1 + 2 * 3 = ?")
print(response)
print(type(response))
# Out:
# System: 你是一个AI助手，你的名字叫小智
# Human: 我的问题是1 + 2 * 3 = ?
# <class 'str'>

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "你是一个AI助手，你的名字叫{name}"),
    ("human", "我的问题是{question}")
])

response = chat_prompt_template.format_messages(name="小智", question="1 + 2 * 3 = ?")
print(response)
print(type(response))
# Out:
# [SystemMessage(content='你是一个AI助手，你的名字叫小智', additional_kwargs={}, response_metadata={}), HumanMessage(content='我的问题是1 + 2 * 3 = ?', additional_kwargs={}, response_metadata={})]
# <class 'list'>

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "你是一个AI助手，你的名字叫{name}"),
    ("human", "我的问题是{question}")
])

response = chat_prompt_template.format_prompt(name="小智", question="1 + 2 * 3 = ?")
print(response)
print(type(response))
# Out:
# messages=[SystemMessage(content='你是一个AI助手，你的名字叫小智', additional_kwargs={}, response_metadata={}), HumanMessage(content='我的问题是1 + 2 * 3 = ?', additional_kwargs={}, response_metadata={})]
# <class 'langchain_core.prompt_values.ChatPromptValue'>

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "你是一个AI助手，你的名字叫{name}"),
    ("human", "我的问题是{question}")
])

response = chat_prompt_template.format_prompt(name="小智", question="1 + 2 * 3 = ?")

response_messages = response.to_messages()
print(response_messages)
print(type(response_messages))
# Out:
# [SystemMessage(content='你是一个AI助手，你的名字叫小智', additional_kwargs={}, response_metadata={}), HumanMessage(content='我的问题是1 + 2 * 3 = ?', additional_kwargs={}, response_metadata={})]
# <class 'list'>

# %%
response_string = response.to_string()
print(response_string)
print(type(response_string))
# Out:
# System: 你是一个AI助手，你的名字叫小智
# Human: 我的问题是1 + 2 * 3 = ?
# <class 'str'>

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages([
    "我的问题是{question}"
])

response = chat_prompt_template.invoke({"question":"1 + 2 * 3 = ?"})
print(response)
# Out:
# messages=[HumanMessage(content='我的问题是1 + 2 * 3 = ?', additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages([
    {"role":"system", "content":"我是一个人工智能助手,我的名字叫{name}"},
    {"role":"human", "content":"我的问题是{question}"}
])

response = chat_prompt_template.invoke({"name":"小智", "question":"1 + 2 * 3 = ?"})
print(response)
# Out:
# messages=[SystemMessage(content='我是一个人工智能助手,我的名字叫小智', additional_kwargs={}, response_metadata={}), HumanMessage(content='我的问题是1 + 2 * 3 = ?', additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages([
    SystemMessage(content="我是一个人工智能助手,我的名字叫{name}"),
    HumanMessage(content="我的问题是{question}")
])

response = chat_prompt_template.invoke({"name":"小智", "question":"1 + 2 * 3 = ?"})
print(response)
# Out:
# messages=[SystemMessage(content='我是一个人工智能助手,我的名字叫{name}', additional_kwargs={}, response_metadata={}), HumanMessage(content='我的问题是{question}', additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.prompts import ChatPromptTemplate

nested_prompt_template1 = ChatPromptTemplate.from_messages([
    ("system", "我是一个人工智能助手,我的名字叫{name}")
])

nested_prompt_template2 = ChatPromptTemplate.from_messages([
    ("human", "我的问题是{question}")
])

chat_prompt_template = ChatPromptTemplate.from_messages([
    nested_prompt_template1,
    nested_prompt_template2
])

response = chat_prompt_template.invoke({"name":"小智", "question":"1 + 2 * 3 = ?"})
print(response)
# Out:
# messages=[SystemMessage(content='我是一个人工智能助手,我的名字叫小智', additional_kwargs={}, response_metadata={}), HumanMessage(content='我的问题是1 + 2 * 3 = ?', additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate, SystemMessagePromptTemplate

system_template = "你是一个专家{role}"
system_message_prompt = SystemMessagePromptTemplate.from_template(system_template)

human_template = "给我解释{concept}，用浅显易懂的语言"
human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)

chat_prompt = ChatPromptTemplate.from_messages([
    system_message_prompt,
    human_message_prompt
])

formatted_messages = chat_prompt.format_messages(
    role="物理学家",
    concept="相对论"
)
print(formatted_messages)
# Out:
# [SystemMessage(content='你是一个专家物理学家', additional_kwargs={}, response_metadata={}), HumanMessage(content='给我解释相对论，用浅显易懂的语言', additional_kwargs={}, response_metadata={})]
